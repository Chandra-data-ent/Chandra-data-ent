# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import datetime
import seaborn as sns
from datetime import date
from google.colab import files
upload = files.upload()
d = pd.read_csv('Demographics.csv')
# Out:
#      <input type="file" id="files-b343d71b-d956-440a-bacb-75f7c0595dc7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b343d71b-d956-440a-bacb-75f7c0595dc7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
d
# Out:
#              Country Name Country Code  Birth rate  Internet users  \
# 0                   Aruba          ABW      10.244            78.9
# 1             Afghanistan          AFG      35.253             5.9
# 2                  Angola          AGO      45.985            19.1
# 3                 Albania          ALB      12.877            57.2
# 4    United Arab Emirates          ARE      11.044            88.0
# ..                    ...          ...         ...             ...
# 190           Yemen, Rep.          YEM      32.947            20.0
# 191          South Africa          ZAF      20.850            46.5
# 192      Congo, Dem. Rep.          COD      42.394             2.2
# 193                Zambia          ZMB      40.471            15.4
# 194              Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ...

# %%
d.to_csv( "demographics2.csv" )

# %%
d.head()
d.head(10)
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244         78.9000
# 1           Afghanistan          AFG      35.253          5.9000
# 2                Angola          AGO      45.985         19.1000
# 3               Albania          ALB      12.877         57.2000
# 4  United Arab Emirates          ARE      11.044         88.0000
# 5             Argentina          ARG      17.716         59.9000
# 6               Armenia          ARM      13.308         41.9000
# 7   Antigua and Barbuda          ATG      16.447         63.4000
# 8             Australia          AUS      13.200         83.0000
# 9               Austria          AUT       9.400         80.6188
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income
# 5          High income
# 6  Lower middle income
# 7          High income
# 8          High income
# ...

# %%
d.tail()
d.tail(7)
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 188  West Bank and Gaza          PSE      30.394            46.6
# 189               Samoa          WSM      26.172            15.3
# 190         Yemen, Rep.          YEM      32.947            20.0
# 191        South Africa          ZAF      20.850            46.5
# 192    Congo, Dem. Rep.          COD      42.394             2.2
# 193              Zambia          ZMB      40.471            15.4
# 194            Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 188  Lower middle income
# 189  Lower middle income
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income

# %%
d.shape
# Out:
# (195, 5)

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    195 non-null    object
#  1   Country Code    195 non-null    object
#  2   Birth rate      195 non-null    float64
#  3   Internet users  195 non-null    float64
#  4   Income Group    195 non-null    object
# dtypes: float64(2), object(3)
# memory usage: 7.7+ KB

# %%
d.describe()
# Out:
#        Birth rate  Internet users
# count  195.000000      195.000000
# mean    21.469928       42.076471
# std     10.605467       29.030788
# min      7.900000        0.900000
# 25%     12.120500       14.520000
# 50%     19.680000       41.000000
# 75%     29.759500       66.225000
# max     49.661000       96.546800

# %%
d.mean()
#Returns the mean of all columns
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# Birth rate        21.469928
# Internet users    42.076471
# dtype: float64

# %%
d.corr()
#Returns the correlation between columns in a data frame
# Out:
#                 Birth rate  Internet users
# Birth rate        1.000000       -0.815589
# Internet users   -0.815589        1.000000

# %%
d.count()
#Returns the number of non-null values in each data frame column
# Out:
# Country Name      195
# Country Code      195
# Birth rate        195
# Internet users    195
# Income Group      195
# dtype: int64

# %%
d.max()
#Returns the highest value in each column
# Out:
# Country Name                 Zimbabwe
# Country Code                      ZWE
# Birth rate                     49.661
# Internet users                96.5468
# Income Group      Upper middle income
# dtype: object

# %%
d.min()
#Returns the lowest value in each column
# Out:
# Country Name      Afghanistan
# Country Code              ABW
# Birth rate                7.9
# Internet users            0.9
# Income Group      High income
# dtype: object

# %%
d.median()
#Returns the median of each column
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# Birth rate        19.68
# Internet users    41.00
# dtype: float64

# %%
d.std()
#Returns the standard deviation of each column
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# Birth rate        10.605467
# Internet users    29.030788
# dtype: float64

# %%
print( d["Birth rate"])
# Out:
# 0      10.244
# 1      35.253
# 2      45.985
# 3      12.877
# 4      11.044
#         ...
# 190    32.947
# 191    20.850
# 192    42.394
# 193    40.471
# 194    35.715
# Name: Birth rate, Length: 195, dtype: float64

# %%
d1 =  d["Birth rate"]
d1
# Out:
# 0      10.244
# 1      35.253
# 2      45.985
# 3      12.877
# 4      11.044
#         ...
# 190    32.947
# 191    20.850
# 192    42.394
# 193    40.471
# 194    35.715
# Name: Birth rate, Length: 195, dtype: float64

# %%
d2 = d[["Birth rate", "Internet users"]]
d2
# Out:
#      Birth rate  Internet users
# 0        10.244            78.9
# 1        35.253             5.9
# 2        45.985            19.1
# 3        12.877            57.2
# 4        11.044            88.0
# ..          ...             ...
# 190      32.947            20.0
# 191      20.850            46.5
# 192      42.394             2.2
# 193      40.471            15.4
# 194      35.715            18.5
#
# [195 rows x 2 columns]

# %%
d.iloc[51]
# Out:
# Country Name                    Egypt
# Country Code                      EGY
# Birth rate                     28.032
# Internet users                   29.4
# Income Group      Lower middle income
# Name: 51, dtype: object

# %%
d.loc[51,'Birth rate']
# Out:
# 28.032

# %%
d.loc[50:60,'Birth rate']
# Out:
# 50    21.070
# 51    28.032
# 52    34.800
# 53     9.100
# 54    10.300
# 55    32.925
# 56    10.700
# 57    20.463
# 58    12.300
# 59    23.511
# 60    30.555
# Name: Birth rate, dtype: float64

# %%
d.loc[50:60,['Country Name','Birth rate' ]]
# Out:
#              Country Name  Birth rate
# 50                Ecuador      21.070
# 51                  Egypt      28.032
# 52                Eritrea      34.800
# 53                  Spain       9.100
# 54                Estonia      10.300
# 55               Ethiopia      32.925
# 56                Finland      10.700
# 57                   Fiji      20.463
# 58                 France      12.300
# 59  Micronesia, Fed. Sts.      23.511
# 60                  Gabon      30.555

# %%
d[d['Birth rate'] < 9]
# Out:
#              Country Name Country Code  Birth rate  Internet users  \
# 45                Germany          DEU         8.5         84.1700
# 68                 Greece          GRC         8.5         59.8663
# 74   Hong Kong SAR, China          HKG         7.9         74.2000
# 86                  Italy          ITA         8.5         58.4593
# 89                  Japan          JPN         8.2         89.7100
# 95            Korea, Rep.          KOR         8.6         84.7700
# 142              Portugal          PRT         7.9         62.0956
# 146               Romania          ROU         8.8         49.7645
#
#             Income Group
# 45           High income
# 68           High income
# 74           High income
# 86           High income
# 89           High income
# 95           High income
# 142          High income
# 146  Upper middle income

# %%
d[d['Birth rate'] >=40]
# Out:
#          Country Name Country Code  Birth rate  Internet users  \
# 2              Angola          AGO      45.985            19.1
# 11            Burundi          BDI      44.151             1.3
# 14       Burkina Faso          BFA      40.551             9.1
# 65        Gambia, The          GMB      42.525            14.0
# 115              Mali          MLI      44.138             3.5
# 127             Niger          NER      49.661             1.7
# 128           Nigeria          NGA      40.045            38.0
# 156           Somalia          SOM      43.891             1.5
# 167              Chad          TCD      45.745             2.3
# 178            Uganda          UGA      43.474            16.2
# 192  Congo, Dem. Rep.          COD      42.394             2.2
# 193            Zambia          ZMB      40.471            15.4
#
#             Income Group
# 2    Upper middle income
# 11            Low income
# 14            Low income
# 65            Low income
# ...

# %%
d[(d['Internet users'] >=30) & (d['Birth rate'] >30) ]
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 91                Kenya          KEN      35.194            39.0
# 128             Nigeria          NGA      40.045            38.0
# 188  West Bank and Gaza          PSE      30.394            46.6
#
#             Income Group
# 91   Lower middle income
# 128  Lower middle income
# 188  Lower middle income

# %%
d[(d['Internet users'] >=95) | (d['Internet users'] <= 5) ]
# Out:
#                  Country Name Country Code  Birth rate  Internet users  \
# 11                    Burundi          BDI      44.151          1.3000
# 13                      Benin          BEN      36.440          4.9000
# 22                    Bermuda          BMU      10.400         95.3000
# 29   Central African Republic          CAF      34.076          3.5000
# 52                    Eritrea          ERI      34.800          0.9000
# 55                   Ethiopia          ETH      32.925          1.9000
# 64                     Guinea          GIN      37.337          1.6000
# 66              Guinea-Bissau          GNB      37.503          3.1000
# 84                    Iceland          ISL      13.400         96.5468
# 99                    Liberia          LBR      35.521          3.2000
# 104                   Lesotho          LSO      28.738          5.0000
# 111                Madagascar          MDG      34.686          3.0000
# ...

# %%
g = d.groupby('Income Group').mean()
g
# Out:
#                      Birth rate  Internet users
# Income Group
# High income           12.753433       74.231684
# Low income            37.238267        5.988333
# Lower middle income   26.309140       22.366386
# Upper middle income   18.740646       40.279577

# %%
d.isnull().sum()
# Out:
# Country Name      0
# Country Code      0
# Birth rate        0
# Internet users    0
# Income Group      0
# dtype: int64

# %%
d.rename(columns={'Internet users': 'new_ name'})
# Out:
#              Country Name Country Code  Birth rate  new_ name  \
# 0                   Aruba          ABW      10.244       78.9
# 1             Afghanistan          AFG      35.253        5.9
# 2                  Angola          AGO      45.985       19.1
# 3                 Albania          ALB      12.877       57.2
# 4    United Arab Emirates          ARE      11.044       88.0
# ..                    ...          ...         ...        ...
# 190           Yemen, Rep.          YEM      32.947       20.0
# 191          South Africa          ZAF      20.850       46.5
# 192      Congo, Dem. Rep.          COD      42.394        2.2
# 193                Zambia          ZMB      40.471       15.4
# 194              Zimbabwe          ZWE      35.715       18.5
#
#             Income Group
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# 190  Lower middle income
# ...

# %%
data_dogs = {'Breed':['Corgi','Golden Retreiver','Boxer'],'Name':['Rex','Bingo','Wolf'], 'Weight':[10,80,70]}
d_dogs = pd.DataFrame(data_dogs)
d_dogs
# Out:
#               Breed   Name  Weight
# 0             Corgi    Rex      10
# 1  Golden Retreiver  Bingo      80
# 2             Boxer   Wolf      70

# %%
data_cats = {'Breed':['Egyptian Mau','Siamese','American Shorthair'],'Name':['Apricot','Lily','June'], 'Weight':[7,8,10]}
d_cats = pd.DataFrame(data_cats)
d_cats
# Out:
#                 Breed     Name  Weight
# 0        Egyptian Mau  Apricot       7
# 1             Siamese     Lily       8
# 2  American Shorthair     June      10

# %%
d_pets = d_cats.append(d_dogs)
d_pets
# Out:
#                 Breed     Name  Weight
# 0        Egyptian Mau  Apricot       7
# 1             Siamese     Lily       8
# 2  American Shorthair     June      10
# 0               Corgi      Rex      10
# 1    Golden Retreiver    Bingo      80
# 2               Boxer     Wolf      70

# %%
nonsense = pd.concat([d_cats, d_dogs],axis=1)
nonsense
# Out:
#                 Breed     Name  Weight             Breed   Name  Weight
# 0        Egyptian Mau  Apricot       7             Corgi    Rex      10
# 1             Siamese     Lily       8  Golden Retreiver  Bingo      80
# 2  American Shorthair     June      10             Boxer   Wolf      70

# %%
#Show the data of the USA
d[d["Country Code"] == "USA"]
# Out:
#       Country Name Country Code  Birth rate  Internet users Income Group
# 181  United States          USA        12.5            84.2  High income

# %%
#Show the countries with birthrate >20 and High income
d[(d["Birth rate"] > 20)]
# Out:
#          Country Name Country Code  Birth rate  Internet users  \
# 1         Afghanistan          AFG      35.253             5.9
# 2              Angola          AGO      45.985            19.1
# 11            Burundi          BDI      44.151             1.3
# 13              Benin          BEN      36.440             4.9
# 14       Burkina Faso          BFA      40.551             9.1
# ..                ...          ...         ...             ...
# 190       Yemen, Rep.          YEM      32.947            20.0
# 191      South Africa          ZAF      20.850            46.5
# 192  Congo, Dem. Rep.          COD      42.394             2.2
# 193            Zambia          ZMB      40.471            15.4
# 194          Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 1             Low income
# 2    Upper middle income
# 11            Low income
# 13            Low income
# 14            Low income
# ..                   ...
# ...

# %%
#Show the data of the country with the highest internet users.
d['Internet users'].max()
# Out:
# 96.5468

# %%
#Show the data of the country with the highest internet users.
d[d['Internet users'] >= 96.5468]
# Out:
#    Country Name Country Code  Birth rate  Internet users Income Group
# 84      Iceland          ISL        13.4         96.5468  High income

# %%
#Average Birthrate
M = d['Birth rate'].mean()
M
# Out:
# 21.469928205128202

# %%
#Standard Deviation of birthrate
SD = d['Birth rate'].std()
SD
# Out:
# 10.605466693579938

# %%
#Countries whose birth rate is two SDs above the mean
d[d['Birth rate'] >= (M + 2*SD) ]
# Out:
#     Country Name Country Code  Birth rate  Internet users         Income Group
# 2         Angola          AGO      45.985            19.1  Upper middle income
# 11       Burundi          BDI      44.151             1.3           Low income
# 115         Mali          MLI      44.138             3.5           Low income
# 127        Niger          NER      49.661             1.7           Low income
# 156      Somalia          SOM      43.891             1.5           Low income
# 167         Chad          TCD      45.745             2.3           Low income
# 178       Uganda          UGA      43.474            16.2           Low income
